# %%
#BA 64060 Fundamentals of Machine Learning
#Assignment 1: Descriptive Statistics
#Step 1: I have picked the data set from my previous class on Data Anylytics
#The data set is called Branch Customers
# Step 2: Import the Data Set into Python

import pandas as pd
df = pd.read_csv("Branch_Customers.csv")
df
# Out:
#                    Name     Branch  Age           Education  Income_K  Deposit
# 0     Shields, Kristian      Solon   70  5. Advanced Degree      69.0  8151.82
# 1          Peck, Hannah   Fairlawn   47          2. HS Grad      58.1  7117.35
# 2        Parker, Claire   Fairlawn   21     4. College Grad      49.7  5751.82
# 3         Sparks, Dylan     Hudson   20        1. < HS Grad      41.4  3162.25
# 4     Sweeten, Michelle      Solon   43     4. College Grad      63.3  5505.66
# ...                 ...        ...  ...                 ...       ...      ...
# 7495   Aguilar, Jessica       Kent   36     3. Some College      47.0  6122.85
# 7496     Buice, Jasahne      Akron   53     3. Some College      57.4  8293.48
# 7497      Quang, Kirill  Twinsburg   48        1. < HS Grad      41.3  4733.30
# 7498      Ho, Rennosuke       Stow   30     3. Some College      33.3  3006.32
# 7499     Peters, Amanda       Kent   45          2. HS Grad      43.3  4238.62
#
# [7500 rows x 6 columns]

# %%
# Step 3(a) Now printing Descriptive Statistics for the quantitiative variables
df.describe()
# Out:
#                Age    Income_K       Deposit
# count  7500.000000  7500.00000   7500.000000
# mean     41.982800    60.29456   7169.826223
# std      11.771397    30.31693   4313.221489
# min      18.000000     3.90000     52.580000
# 25%      33.000000    41.60000   4598.807500
# 50%      42.000000    54.95000   6263.645000
# 75%      50.000000    71.20000   8491.982500
# max      83.000000   232.80000  34589.390000

# %%
#Step 3 (b) Next printing Descriptive statistics for the categorical variables
df.describe(include=['object'])
# Out:
#                   Name    Branch   Education
# count             7500      7500        7500
# unique            7464         7           5
# top     Turner, Andrew  Fairlawn  2. HS Grad
# freq                 3      1927        2416

# %%
#Step 3 (c) Next doign value counts for a categorical variable 'Education'
df['Education'].value_counts()
# Out:
# Education
# 2. HS Grad            2416
# 4. College Grad       1715
# 3. Some College       1617
# 5. Advanced Degree    1082
# 1. < HS Grad           670
# Name: count, dtype: int64

# %%
df.Education
# Out:
# 0       5. Advanced Degree
# 1               2. HS Grad
# 2          4. College Grad
# 3             1. < HS Grad
# 4          4. College Grad
#                ...
# 7495       3. Some College
# 7496       3. Some College
# 7497          1. < HS Grad
# 7498       3. Some College
# 7499            2. HS Grad
# Name: Education, Length: 7500, dtype: category
# Categories (5, object): ['1. < HS Grad', '2. HS Grad', '3. Some College', '4. College Grad',
#                          '5. Advanced Degree']

# %%
# Step 4: Transforming the "Education" Categorical Variable using an Ordinal Transformation
# First step is to change the data type into "Categorical"
df.Education= df.Education.astype('category')

#Second step is to provide the correct order of categories
df.Education= df.Education.cat.reorder_categories(['1. < HS Grad','2. HS Grad','3. Some College','4. College Grad','5. Advanced Degree'])

#Third step is to encode categories with integer values
df.Education= df.Education.cat.codes
df
# Out:
#                    Name     Branch  Age  Education  Income_K  Deposit
# 0     Shields, Kristian      Solon   70          4      69.0  8151.82
# 1          Peck, Hannah   Fairlawn   47          1      58.1  7117.35
# 2        Parker, Claire   Fairlawn   21          3      49.7  5751.82
# 3         Sparks, Dylan     Hudson   20          0      41.4  3162.25
# 4     Sweeten, Michelle      Solon   43          3      63.3  5505.66
# ...                 ...        ...  ...        ...       ...      ...
# 7495   Aguilar, Jessica       Kent   36          2      47.0  6122.85
# 7496     Buice, Jasahne      Akron   53          2      57.4  8293.48
# 7497      Quang, Kirill  Twinsburg   48          0      41.3  4733.30
# 7498      Ho, Rennosuke       Stow   30          2      33.3  3006.32
# 7499     Peters, Amanda       Kent   45          1      43.3  4238.62
#
# [7500 rows x 6 columns]

# %%
#5a Plot one Quantitative Variable
import matplotlib.pyplot as plt
plt.hist(df.Income_K)
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %%
#Step 5b: Scatter Plot of Age and Deposit
import matplotlib.pyplot as plt
plt.scatter(df.Age,df.Deposit)
plt.xlabel('Age')
plt.ylabel('Deposit')
plt.show()
